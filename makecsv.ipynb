# %%
import pandas as pd

# %%
# jan19 = pd.read_csv('Citi/201901-citibike-tripdata.csv')
# feb19 = pd.read_csv('Citi/201902-citibike-tripdata.csv')
# mar19 = pd.read_csv('Citi/201903-citibike-tripdata.csv')
# apr19 = pd.read_csv('Citi/201904-citibike-tripdata.csv')
# may19 = pd.read_csv('Citi/201905-citibike-tripdata.csv')
# jun19 = pd.read_csv('Citi/201906-citibike-tripdata.csv')
# jul19 = pd.read_csv('Citi/201907-citibike-tripdata.csv')
# aug19 = pd.read_csv('Citi/201908-citibike-tripdata.csv')
# sep19 = pd.read_csv('Citi/201909-citibike-tripdata.csv')
# oct19 = pd.read_csv('Citi/201910-citibike-tripdata.csv')
# nov19 = pd.read_csv('Citi/201911-citibike-tripdata.csv')
# dec19 = pd.read_csv('Citi/201912-citibike-tripdata.csv')

jan20 = pd.read_csv('Citi/202001-citibike-tripdata.csv')
feb20 = pd.read_csv('Citi/202002-citibike-tripdata.csv')
mar20 = pd.read_csv('Citi/202003-citibike-tripdata.csv')
apr20 = pd.read_csv('Citi/202004-citibike-tripdata.csv')
may20 = pd.read_csv('Citi/202005-citibike-tripdata.csv')
jun20 = pd.read_csv('Citi/202006-citibike-tripdata.csv')
jul20 = pd.read_csv('Citi/202007-citibike-tripdata.csv')
aug20 = pd.read_csv('Citi/202008-citibike-tripdata.csv')
sep20 = pd.read_csv('Citi/202009-citibike-tripdata.csv')
oct20 = pd.read_csv('Citi/202010-citibike-tripdata.csv')
nov20 = pd.read_csv('Citi/202011-citibike-tripdata.csv')
dec20 = pd.read_csv('Citi/202012-citibike-tripdata.csv')

# %%
# jan19.head(4)

# %%
jan20.head(4)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
#
#    start station longitude  end station id           end station name  \
# 0               -73.981656             307      Canal St & Rutgers St
# 1               -73.979453            3300  Prospect Park West & 8 St
# ...

# %%
# covid19 = pd.concat([jan19,feb19,mar19,apr19,may19,jun19,jul19,aug19,sep19,oct19,nov19,dec19], ignore_index= True)
covid20 = pd.concat([jan20,feb20,mar20,apr20,may20,jun20,jul20,aug20,sep20,oct20,nov20,dec20], ignore_index= True)

# %%
# covid19.columns

# %%
covid20.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
# covid19[['stardate', 'startime']] = covid19['starttime'].str.split(' ', expand= True)

covid20.tail()
# Out:
#           tripduration                 starttime                  stoptime  \
# 19506852          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 19506853           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 19506854           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 19506855           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 19506856          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#           start station id                   start station name  \
# 19506852               526                      E 33 St & 5 Ave
# 19506853              3307               West End Ave & W 94 St
# 19506854              3510  Adam Clayton Powell Blvd & W 123 St
# 19506855              4073          W 51 St & Rockefeller Plaza
# 19506856              3581           Underhill Ave & Lincoln Pl
#
#           start station latitude  start station longitude  end station id  \
# ...

# %%
# covid19.head()

# %%
covid20[['stardate', 'startime']] = covid20['starttime'].str.split(' ', expand= True)

# %%
# covid19[['enddate', 'endtime']] = covid19['stoptime'].str.split(' ', expand= True)

# %%
covid20[['enddate', 'endtime']] = covid20['stoptime'].str.split(' ', expand= True)

# %%
# covid19['stardate'] = pd.to_datetime(covid19['stardate'])
# covid19['startime'] = pd.to_datetime(covid19['startime'], format='%T').dt.time

# %%
covid20.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# ...

# %%
# covid20['date'] = pd.to_datetime(covid20['date'])
# covid20['time'] = pd.to_datetime(covid20['time'], format= '%H:%M:%S').dt.time

# %%
covid20.tail()
# Out:
#           tripduration                 starttime                  stoptime  \
# 19506852          2045  2020-12-31 23:58:21.7040  2021-01-01 00:32:27.1570
# 19506853           288  2020-12-31 23:58:37.8400  2021-01-01 00:03:26.3250
# 19506854           152  2020-12-31 23:58:52.8090  2021-01-01 00:01:25.6720
# 19506855           654  2020-12-31 23:59:55.9550  2021-01-01 00:10:50.6050
# 19506856          2589  2020-12-31 23:59:57.4070  2021-01-01 00:43:06.4490
#
#           start station id                   start station name  \
# 19506852               526                      E 33 St & 5 Ave
# 19506853              3307               West End Ave & W 94 St
# 19506854              3510  Adam Clayton Powell Blvd & W 123 St
# 19506855              4073          W 51 St & Rockefeller Plaza
# 19506856              3581           Underhill Ave & Lincoln Pl
#
#           start station latitude  start station longitude  end station id  \
# ...

# %%
# covidbike = pd.concat([covid20], ignore_index= True)

# %%
covid20.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           789  2020-01-01 00:00:55.3900  2020-01-01 00:14:05.1470
# 1          1541  2020-01-01 00:01:08.1020  2020-01-01 00:26:49.1780
# 2          1464  2020-01-01 00:01:42.1400  2020-01-01 00:26:07.0110
# 3           592  2020-01-01 00:01:45.5610  2020-01-01 00:11:38.1550
# 4           702  2020-01-01 00:01:45.7880  2020-01-01 00:13:28.2400
#
#    start station id               start station name  start station latitude  \
# 0               504                  1 Ave & E 16 St               40.732219
# 1              3423  West Drive & Prospect Park West               40.661063
# 2              3687                  E 33 St & 1 Ave               40.743227
# 3               346              Bank St & Hudson St               40.736529
# 4               372        Franklin Ave & Myrtle Ave               40.694546
#
#    start station longitude  end station id           end station name  \
# ...

# %%
covid20.to_csv('covid20.csv', index= False)
